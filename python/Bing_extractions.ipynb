# %%
import requests

# %%
subscription_key = "cebbe96d655f493aa0fa19a5b2ba7028"
search_url = "https://brazilsouth.api.cognitive.microsoft.com/bing/v7.0/search/"
search_term = "\"Tissue source such as\""

# %%
headers = {"Ocp-Apim-Subscription-Key" : subscription_key}
params  = {"q": search_term, "count": 50 }#, "textDecorations":True, "textFormat":"HTML"}
response = requests.get(search_url, headers=headers, params=params)
response.raise_for_status()
search_results = response.json()

# %%
search_results
# Out:
# {'_type': 'SearchResponse',
#  'queryContext': {'originalQuery': '"Tissue source such as"'},
#  'rankingResponse': {'mainline': {'items': [{'answerType': 'WebPages',
#      'resultIndex': 0,
#      'value': {'id': 'https://brazilsouth.api.cognitive.microsoft.com/api/v7/#WebPages.0'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 1,
#      'value': {'id': 'https://brazilsouth.api.cognitive.microsoft.com/api/v7/#WebPages.1'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 2,
#      'value': {'id': 'https://brazilsouth.api.cognitive.microsoft.com/api/v7/#WebPages.2'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 3,
#      'value': {'id': 'https://brazilsouth.api.cognitive.microsoft.com/api/v7/#WebPages.3'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 4,
#      'value': {'id': 'https://brazilsouth.api.cognitive.microsoft.com/api/v7/#WebPages.4'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 5,
# ...

# %%
count = 0
for i in search_results["webPages"]["value"]:
    print(i["snippet"] + "\n")
    count +=1
print(count)
# Out:
# Tissue source provides custom porcine tissue and other animal tissue to medical and educational institutions.
#
# Start studying Nutrient Sources and Functions. Learn vocabulary, terms, and more with flashcards, games, and other study tools.
#
# With the emergence of more and more sophisticated techniques for gene expression analysis (e.g. array analysis, real-time RT-PCR), the quality of the RNA ...
#
# Study uses alternative tissue source for breast reconstruction. Study uses alternative tissue source for breast reconstruction
#
# Ongoing progress towards the clinical use of dental stem cells has recently expanded the possibilities for clinical applications. Here's what is happening.
#
# BioAssay record AID 39040 submitted by ChEMBL: Concentration required for 50% inhibition of binding against Angiotensin II receptor in the bovine adrenal cortex tissue.
#
# What actual is a cell culture ? Get the answers you need, now!
#
# ...
